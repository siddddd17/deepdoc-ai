# %%
import traceback
import sys
from logger.custom_logger import CustomLogger
class DeepDocException(Exception):
    """Base exception for all DeepDoc errors"""
    def __init__(self,error_message):
        _,_,exc_tb= sys.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*sys.exc_info())) 
        
    def __str__(self):
       return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback:
        {self.traceback_str}
        """

# %%
try:
    # Simulate an error
    a = 1 / 0
    print(a)
except Exception as e:
    app_exc=DeepDocException(e)
    print(app_exc)
    raise app_exc
# Out:
#         Error in [/var/folders/bd/9q7wmtj93pn3qtrmkxq7bpth0000gn/T/ipykernel_14936/2577420619.py] at line [3]
#         Message: division by zero
#         Traceback:
#         Traceback (most recent call last):
#   File "/var/folders/bd/9q7wmtj93pn3qtrmkxq7bpth0000gn/T/ipykernel_14936/2577420619.py", line 3, in <module>
#     a = 1 / 0
# ZeroDivisionError: division by zero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 try:
#       2     # Simulate an error
# ----> 3     a = 1 / 0
#       4     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DeepDocException                          Traceback (most recent call last)
# Cell In[4], line 8
#       6 app_exc=DeepDocException(e)
#       7 print(app_exc)
# ----> 8 raise app_exc
#
# DeepDocException:
#         Error in [/var/folders/bd/9q7wmtj93pn3qtrmkxq7bpth0000gn/T/ipykernel_14936/2577420619.py] at line [3]
#         Message: division by zero
#         Traceback:
#         Traceback (most recent call last):
#   File "/var/folders/bd/9q7wmtj93pn3qtrmkxq7bpth0000gn/T/ipykernel_14936/2577420619.py", line 3, in <module>
#     a = 1 / 0
# ZeroDivisionError: division by zero
